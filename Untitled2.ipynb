# %% [markdown]
# <a href="https://colab.research.google.com/github/EperorChoyboy/-fa4programactivity/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number = int(input("Enter a number: "))

if number % 2 == 0:
  print(f"{number} is an even number.")
else:
  print(f"{number} is an odd number.")
# Out:
# Enter a number: 2
# 2 is an even number.
